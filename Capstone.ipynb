# %%
import pandas as pd

# %% [markdown]
# Read in first data set.

# %%
df1 = pd.read_csv('KYRC24_OVW_Teacher_Working_Conditions.csv')

print(df1.head())
# Out:
#    School Year  County Number County Name  District Number  District Name  \
# 0     20232024            NaN         NaN              999  All Districts
# 1     20232024            NaN         NaN              999  All Districts
# 2     20232024            NaN         NaN              999  All Districts
# 3     20232024            1.0       ADAIR                1   Adair County
# 4     20232024            1.0       ADAIR                1   Adair County
#
#    School Number  School Name  School Code  State School Id  NCES ID  CO-OP  \
# 0            NaN  All Schools       999000              NaN      NaN    909
# 1            NaN  All Schools       999000              NaN      NaN    909
# 2            NaN  All Schools       999000              NaN      NaN    909
# 3            NaN  All Schools         1000              NaN      NaN    902
# 4            NaN  All Schools         1000              NaN      NaN    902
#
# ...

# %%
df1.info(
)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4305 entries, 0 to 4304
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   School Year      4305 non-null   int64
#  1   County Number    4302 non-null   float64
#  2   County Name      4302 non-null   object
#  3   District Number  4305 non-null   int64
#  4   District Name    4305 non-null   object
#  5   School Number    3789 non-null   float64
#  6   School Name      4305 non-null   object
#  7   School Code      4305 non-null   int64
#  8   State School Id  3789 non-null   float64
#  9   NCES ID          3789 non-null   float64
#  10  CO-OP            4305 non-null   int64
#  11  CO-OP Code       4146 non-null   object
#  12  School Type      3789 non-null   object
#  13  Impact Measure   4305 non-null   object
#  14  Impact Value     4305 non-null   int64
# dtypes: float64(4), int64(5), object(6)
# memory usage: 504.6+ KB

# %%
df1.describe(
)
# Out:
#        School Year  County Number  District Number  School Number  \
# count       4305.0    4302.000000      4305.000000    3789.000000
# mean    20232024.0      56.334728       302.751916     112.679335
# std            0.0      32.310291       189.631225     155.949339
# min     20232024.0       1.000000         1.000000       2.000000
# 25%     20232024.0      34.000000       156.000000      21.000000
# 50%     20232024.0      56.000000       275.000000      60.000000
# 75%     20232024.0      80.000000       461.000000     130.000000
# max     20232024.0     120.000000       999.000000     980.000000
#
#          School Code  State School Id       NCES ID        CO-OP  Impact Value
# count    4305.000000     3.789000e+03  3.789000e+03  4305.000000   4305.000000
# mean   302851.089895     5.658186e+07  2.102775e+11   904.820906     67.134030
# std    189646.446611     3.212147e+07  1.674417e+08     2.835275     16.995624
# ...

# %% [markdown]
# Renamed this spreadsheet.

# %%
Working_Conditions_df = df1

# %%
print(Working_Conditions_df.columns)
# Out:
# Index(['School Year', 'County Number', 'County Name', 'District Number',
#        'District Name', 'School Number', 'School Name', 'School Code',
#        'State School Id', 'NCES ID', 'CO-OP', 'CO-OP Code', 'School Type',
#        'Impact Measure', 'Impact Value'],
#       dtype='object')

# %%
df_dropped_columns_Working_Conditions = Working_Conditions_df.drop(columns = ['County Number', 'County Name', 'School Number', 'School Name', 'School Code', 'School Type', 'CO-OP','CO-OP Code','NCES ID','State School Id', 'School Number', 'School Type'])

# %%
df_dropped_columns_Working_Conditions.head(20)
# Out:
#     School Year  District Number  District Name             Impact Measure  \
# 0      20232024              999  All Districts  Managing Student Behavior
# 1      20232024              999  All Districts             School Climate
# 2      20232024              999  All Districts          School Leadership
# 3      20232024                1   Adair County  Managing Student Behavior
# 4      20232024                1   Adair County             School Climate
# 5      20232024                1   Adair County          School Leadership
# 6      20232024                1   Adair County  Managing Student Behavior
# 7      20232024                1   Adair County             School Climate
# 8      20232024                1   Adair County          School Leadership
# 9      20232024                1   Adair County  Managing Student Behavior
# 10     20232024                1   Adair County             School Climate
# ...

# %% [markdown]
# Read in second data set.

# %%
df_Teacher_Turnover = pd.read_csv('KYRC24_OVW_Teacher_Turnover (1).csv')

print(df_Teacher_Turnover.head())
# Out:
#    School Year  County Number County Name  District Number  District Name  \
# 0     20232024            NaN         NaN              999  All Districts
# 1     20232024            1.0       ADAIR                1   Adair County
# 2     20232024            1.0       ADAIR                1   Adair County
# 3     20232024            1.0       ADAIR                1   Adair County
# 4     20232024            1.0       ADAIR                1   Adair County
#
#    School Number                 School Name  School Code  State School Id  \
# 0            NaN                 All Schools       999000              NaN
# 1            NaN                 All Schools         1000              NaN
# 2           10.0    Adair County High School         1010        1001010.0
# 3           12.0      Adair Learning Academy         1012        1001012.0
# 4           14.0  Adair County Middle School         1014        1001014.0
#
#         NCES ID  CO-OP CO-OP Code School Type Teacher Count  \
# ...

# %%
df_dropped_columns_Teacher_Turnover = df_Teacher_Turnover.drop(columns = ['County Number', 'County Name', 'School Number', 'School Name', 'School Code', 'School Type', 'CO-OP','CO-OP Code','NCES ID','State School Id', 'School Number', 'School Type'])

# %%
df_dropped_columns_Teacher_Turnover.head(20)
# Out:
#     School Year  District Number          District Name Teacher Count  \
# 0      20232024              999          All Districts        49,691
# 1      20232024                1           Adair County           203
# 2      20232024                1           Adair County            61
# 3      20232024                1           Adair County             5
# 4      20232024                1           Adair County            49
# 5      20232024                1           Adair County            41
# 6      20232024                1           Adair County            47
# 7      20232024                5           Allen County           196
# 8      20232024                5           Allen County            60
# 9      20232024                5           Allen County            30
# 10     20232024                5           Allen County            61
# 11     20232024                5           Allen County             3
# ...

# %%
df_Teacher_Salary = pd.read_excel('Average Certified Salaries.xlsx')

print(df_Teacher_Salary.head(10))
# Out:
#   AVERAGE TOTAL CERTIFIED SALARY      Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0         1989-90 THROUGH 2024-25            NaN        NaN        NaN
# 1                             NaN            NaN        NaN        NaN
# 2                         Dist No  District name    1989-90    1990-91
# 3                             001         ADAIR       26903      29085
# 4                             005         ALLEN       26926      29315
# 5                             006      ANCHORAGE      30793      34532
# 6                             011      ANDERSON       26356      29228
# 7                             012        ASHLAND      28958      32152
# 8                             013        AUGUSTA      25621      28676
# 9                             015       BALLARD       27265      29814
#
#   Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ...  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN  ...
# ...

# %%
print(df_Teacher_Salary.columns)
# Out:
# Index(['AVERAGE TOTAL CERTIFIED SALARY ', 'Unnamed: 1', 'Unnamed: 2',
#        'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7',
#        'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12',
#        'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16',
#        'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20',
#        'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24',
#        'Unnamed: 25', 'Unnamed: 26', 'Unnamed: 27', 'Unnamed: 28',
#        'Unnamed: 29', 'Unnamed: 30', 'Unnamed: 31', 'Unnamed: 32',
#        'Unnamed: 33', 'Unnamed: 34', 'Unnamed: 35', 'Unnamed: 36',
#        'Unnamed: 37', 'Unnamed: 38'],
#       dtype='object')

# %%
df_Teacher_Salary.head(20)
# Out:
#    AVERAGE TOTAL CERTIFIED SALARY      Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0          1989-90 THROUGH 2024-25            NaN        NaN        NaN
# 1                              NaN            NaN        NaN        NaN
# 2                          Dist No  District name    1989-90    1990-91
# 3                              001         ADAIR       26903      29085
# 4                              005         ALLEN       26926      29315
# 5                              006      ANCHORAGE      30793      34532
# 6                              011      ANDERSON       26356      29228
# 7                              012        ASHLAND      28958      32152
# 8                              013        AUGUSTA      25621      28676
# 9                              015       BALLARD       27265      29814
# 10                             016   BARBOURVILLE      24923      27858
# 11                             017      BARDSTOWN      28795      31723
# ...
